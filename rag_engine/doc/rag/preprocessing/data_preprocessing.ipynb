# %%
# 청구항 정리만
import os
import re
import xml.etree.ElementTree as ET

xml_files = [f for f in os.listdir('../../data/raw_data') if f.endswith('.xml')]

results = []

for i in range(len(xml_files)):  
    file_path = os.path.join('../../data/raw_data', xml_files[i]) 
    tree = ET.parse(file_path)  
    root = tree.getroot()  
    
    data = {}

    data["id"] = re.sub(r'\D', '', xml_files[i])

    # 출원 번호
    elem1 = root.find('.//biblioSummaryInfo')
    title = elem1.findtext('inventionTitle', '') if elem1 is not None else ''
    
    # 요약
    elem2 = root.find('.//abstractInfoArray/abstractInfo')
    abstract = elem2.findtext('astrtCont', '')  if elem2 is not None else ''

    # 청구항
    claims = {}

    for elem in root.findall('.//claimInfoArray/claimInfo/claim'):
        full = elem.text.strip()            
        num = full.split('.')[0]          
        value = full.split('.', 1)[1].strip()
        claims[f"claim{num}"] = value

    for claim_key in claims:
        claim_text = claims[claim_key]

        claim_text = re.sub(r"(?:제\s*\d+\s*항|청구항\s*\d+)\s*에\s*있어서,?", "", claim_text).strip()
        
        claims[claim_key] = {
            "content": claim_text,
        }

    data["embed"] = {'name':title, 'abstract':abstract, 'claim':claims}

    # IPC
    ipc = []

    for elem in root.findall('.//ipcInfoArray/ipcInfo/ipcNumber'):
        text = elem.text or ''
        ipc.append(text if text else '')

    # 우선권(국가)
    elem5 = root.find('.//priorityInfoArray/priorityInfo')
    country = elem5.findtext('priorityApplicationCountry', '') if elem5 is not None else ''

    # 공개/거절
    status = elem1.findtext('registerStatus', '') if elem1 is not None else ''

    # 링크
    elem6 = root.find('.//imagePathInfo')
    link = elem6.findtext('largePath', '') if elem6 is not None else ''

    data["metadata"] = {'ipc':ipc, 'priority':country, 'register':status, 'link':link}

    results.append(data)

# %%
# independent 추가
import os
import re
import xml.etree.ElementTree as ET

xml_files = [f for f in os.listdir('../../data/raw_data') if f.endswith('.xml')]

results = []

for i in range(len(xml_files)):  
    file_path = os.path.join('../../data/raw_data', xml_files[i]) 
    tree = ET.parse(file_path)  
    root = tree.getroot()  
    
    data = {}

    data["id"] = re.sub(r'\D', '', xml_files[i])

    # 출원 번호
    elem1 = root.find('.//biblioSummaryInfo')
    title = elem1.findtext('inventionTitle', '') if elem1 is not None else ''
    
    # 요약
    elem2 = root.find('.//abstractInfoArray/abstractInfo')
    abstract = elem2.findtext('astrtCont', '')  if elem2 is not None else ''

    # 청구항
    claims = {}

    for elem in root.findall('.//claimInfoArray/claimInfo/claim'):
        full = elem.text.strip()            
        num = full.split('.')[0]          
        value = full.split('.', 1)[1].strip()
        claims[f"claim{num}"] = value

    for claim_key in claims:
        claim_text = claims[claim_key]
        
        independent = not bool(re.search(r"(?:제\s*\d+\s*항|청구항\s*\d+)\s*에\s*있어서,?", claim_text))

        claim_text = re.sub(r"(?:제\s*\d+\s*항|청구항\s*\d+)\s*에\s*있어서,?", "", claim_text).strip()
        
        claims[claim_key] = {
            "content": claim_text,
            "independent": independent
        }

    data["embed"] = {'name':title, 'abstract':abstract, 'claim':claims}

    # IPC
    ipc = []

    for elem in root.findall('.//ipcInfoArray/ipcInfo/ipcNumber'):
        text = elem.text or ''
        ipc.append(text if text else '')

    # 우선권(국가)
    elem5 = root.find('.//priorityInfoArray/priorityInfo')
    country = elem5.findtext('priorityApplicationCountry', '') if elem5 is not None else ''

    # 공개/거절
    status = elem1.findtext('registerStatus', '') if elem1 is not None else ''

    # 링크
    elem6 = root.find('.//imagePathInfo')
    link = elem6.findtext('largePath', '') if elem6 is not None else ''

    data["metadata"] = {'ipc':ipc, 'priority':country, 'register':status, 'link':link}

    results.append(data)

# %%
results
# Out:
# [{'id': '1020050108060',
#   'embed': {'name': '정보 교류 기능을 가진 단말기, 이를 이용한 정보 교류시스템 및 방법',
#    'abstract': ' 본 발명에 따른 단말기는 근거리 무선 통신을 통해 주변의 타 단말기 또는 서버와 정보를 교류할 수 있다. 또한 단말기 또는 서버는 자체에 데이터베이스를 구비하고 있어 타 단말기를 상대로 서비스 항목 정보를 교류 또는 GPS와 연계된 식별정보 등을 송수신할 수 있다. 본 발명의 특징적인 양상은 이 같은 단말기들이 주변의 타 단말기들의 식별정보, 위치정보와 같은 상황 정보를 직접 또는 서버로부터 수집하여 매 시각별로 저장함으로써 주변의 타 단말기 소지자들과 정보를 교류하거나 특정한 시각의 당시 주위 단말기 배치 상황을 조회할 수 있도록 할 수도 있다.단말기, 미팅, 리서치, 고유정보, 서비스 항목 정보, 전자 상거래, 식별정보, GPS, 지도, 상황도, GIS',
#    'claim': {'claim1': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 단말기로서,상기 다른 단말기와의 통신 기능을 수행하는 통신부;단말기의 식별정보를 포함한 정보를 저장하는 메모리;상기 통신부를 통해 상기 다른 단말기에 원하는 정보를 요청하고, 요청된 정보를 수신하여 해당 서비스를 수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim2': {'content': 'GPS 위성의 신호를 수신하여 위치 계산에 필요한 정보를 출력하는 GPS 모듈을 더 포함하며, 상기 제어부는 상기 다른 단말기들의 위치 정보를 입력받고, 입력받은 다른 단말기의 위치와 자신의 위치로부터 상황도 정보를 생성하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim3': {'content': '상기 제어부는,수신된 다른 단말기의 식별정보를 포함한 정보를 저장하는 주변 단말기 등록부와;외부로부터의 요구에 응답하여 상기 메모리에 저장된 주변 단말기들의 정보를 출력하는 주변 단말기 조회부를 포함하는 단말기.',
#      'independent': False},
#     'claim4': {'content': '상기 주변 단말기 등록부는 상기 타 단말기로부터 식별정보를 수신하여 상기 메모리에 저장함에 있어서 식별 정보, 수수시각 정보를 함께 저장하고, 상기 주변 단말기 조회부는 상기 메모리에 저장된 주변 단말기 정보를 출력함에 있어서 함께 저장된 식별 정보 수수 시각 별로 출력하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim5': {'content': '단말기에 충격이 가해지는 것을 감지하는 충격 감지 센서를 더 포함하며, 상기 제어부는 상기 충격 감지센서로부터 충격이 감지되면, 상기 통신부를 통해 미리 설정된 긴급 연락처로 접속하여 긴급상황을 알리는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim6': {'content': '상기 제어부는,자동차의 위치정보 및 주행 정보를 저장하는 도로 정보 처리 모듈을 더 포함하는 단말기.',
#      'independent': False},
#     'claim7': {'content': '상기 제어부가 수행하는 서비스는, 미팅신청, 전자상거래, 긴급상황, 도로공사, 리서치, 공동구매, 역경매, 금융중 적어도 하나를 포함하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim8': {'content': '주변의 다른 적어도 하나의 단말기 및 서버와 통신하며 정보를 교류하는 단말기로서,상기 다른 단말기 또는 상기 서버와의 통신 기능을 수행하는 통신부;단말기의 식별정보를 포함한 정보를 저장하는 메모리;상기 통신부를 통해 상기 서버에 상기 다른 단말기의 정보를 요청하고, 요청된 정보를 수신하여 해당 서비스를 수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim9': {'content': 'GPS 위성의 신호를 수신하여 위치 계산에 필요한 정보를 출력하는 GPS 모듈을 더 포함하며, 상기 제어부는 상기 서버로부터 자신과 다른 단말기들의 위치 정보가 나타난 상황도를 입력받고, 상기 서비스를 수행하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim10': {'content': '상기 제어부는 서비스가 미팅일 경우, 상기 상황도의 다른 단말기중 상대 단말기를 선택하여 미팅 제의 내용을 송신하고, 상대 단말기의 수락에 따라 정보를 송수신하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim11': {'content': '상기 제어부는 서비스가 도로공사 서비스일 경우, 상기 서버로부터 목적지 및 출발지에 관한 요금정보를 입력받아 결제하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim12': {'content': '주변의 다른 적어도 하나의 단말기 및 서버와 통신하며 정보를 교류하는 단말기로서,상기 다른 단말기 또는 상기 서버와의 통신 기능을 수행하는 통신부;단말기의 식별정보를 포함한 정보를 저장하는 메모리;사용자의 선택을 입력받는 입력부;상기 통신부를 통해 상기 다른 단말기에 필요한 정보를 요청하고, 요청된 정보를 수신하여 상기 입력부에서 선택되는 서비스를 수행하고, 그 결과를 상기 서버로 송신하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim13': {'content': '상기 제어부는 상기 서비스가 전자상거래일 경우 상기 다른 단말기로부터 상품정보를 입력받아 전자상거래를 수행한후 그 결과를 상기 서버로 송신하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim14': {'content': '상기 제어부는 상기 다른 단말기의 소정의 정보를 수신하기 위해 소정의 요금을 결제하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim15': {'content': '적어도 하나의 제1 단말기와 통신하며, 정보를 교류하는 정보 교류 시스템으로서,제1 단말기를 포함하는 복수의 무선단말기 식별정보 및 그에 대응하는 서비스 정보를 저장하는 데이터베이스;상기 제1 단말기로부터 입력되는 서비스 요청 정보에 따라 그에 대응되는 서비스 정보를 상기 제1 단말기로 송신하는 서버를 포함하는 정보 교류 시스템.',
#      'independent': True},
#     'claim16': {'content': '상기 서버는 상기 제1 단말기가 긴급 상황임을 알리면, 상기 데이터베이스에 저장된 제1 단말기에 대응되는 긴급 연락처로 현재의 상황을 알리는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim17': {'content': '상기 서버는 상기 제1 단말기가 자신의 주변 상황에 대한 정보를 요청하면, 상기 제1 단말기와 제1 단말기로부터 소정의 거리에 위치한 단말기들의 위치 정보를 결합한 상황도 정보를 상기 제1 단말기 또는 외부에 위치한 적어도 하나의 정보기기로 송신하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim18': {'content': '상기 서버는 상기 제1 단말기가 전자 상거래 대상인 제2 단말기의  정보를 요청하면, 제2 단말기의 상품 관련 정보를 상기 제1 단말기에 송신하고, 주문시에 결제처리를 하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim19': {'content': '상기 서버는 상기 제1 단말기가 미팅 대상인 제2 단말기의  정보를 요청하면, 소정의 금액 결제후, 제2 단말기 소유자의 인적사항 정보를 상기 제1 단말기에 송신하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim20': {'content': '상기 서버는 상기 제1 단말기가 도로공사의 고속도로 요금 정보를 요청하면, 목적지 및 출발지에 따라 금액 정보를 제공하고, 금액 결제후 도로 공사 서버로 단말기 정보, 차량정보, 결제 정보, 목적지 및 출발지 정보를 송신하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim21': {'content': '적어도 하나의 제1 단말기와 통신하며, 이동통신사 서버로부터 상기 제1 단말기를 포함한 단말기들의 위치 정보인 상황도 정보를 수신하여 정보를 교류하는 정보 교류 시스템으로서,제1 단말기를 포함하는 복수의 무선단말기 식별정보 및 그에 대응하는 서비스 정보를 저장하는 데이터베이스;상기 제1 단말기로부터 입력되는 서비스 요청 정보에 따라 그에 대응되는 서비스 정보 및 상기 상황도 정보를 상기 제1 단말기로 송신하는 서버를 포함하는 정보 교류 시스템.',
#      'independent': True},
#     'claim22': {'content': '데이터베이스 및 서버를 구비하고, 적어도 하나의 제1 단말기와 통신하며, 정보를 교류하는 정보 교류 방법으로서,상기 제1 단말기가 자신의 식별정보와 함께 서비스 요청 정보를 상기 서버로 송신하는 단계;상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계를 포함하는 정보 교류 방법.',
#      'independent': True},
#     'claim23': {'content': '상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계는, 상기 서버가 상기 식별정보에 포함된 상기 제1 단말기의 위치정보와 상기 제1 단말기로부터 소정의 거리에 위치한 단말기들의 위치 정보를 결합한 상황도 정보를 송신하는 단계를 포함하는 것을 특징으로 하는 정보 교류 방법.',
#      'independent': False},
#     'claim24': {'content': '상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계는, 서비스가 미팅일 경우, 상기 제1 단말기로부터 선택된 제2 단말기의 정보가 수신되면, 상기 서버가 상기 제2 단말기의 상세 정보를 상기 제1 단말기로 송신하는 단계를 더 포함하는 것을 특징으로 하는 정보 교류 방법.',
#      'independent': False},
#     'claim25': {'content': '상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계는,상기 서비스가 도로공사 서비스일 경우, 상기 서버가 목적지 및 출발지에 관한 요금정보를 입력받아 결제하는 단계를 더 포함하는 것을 특징으로 하는 정보 교류 방법.',
#      'independent': False}}},
#   'metadata': {'ipc': ['H04M 3/42', 'H04B 1/40', 'G06F 17/00', 'G06Q 30/06'],
#    'priority': '대한민국',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=452306798ef1fd035bfb5ff666db4c9c592fb536ea920a4d00a52c7cb74f75b34e9968e7031a190dadda0b8843d15a1b'}},
#  {'id': '1020057007135',
#   'embed': {'name': 'ＤＶＢ-Ｔ용 이동 멀티미디어 단말기 및 대규모와 소규모셀 통신',
#    'abstract': '상호작용 이동 멀티미디어 단말기(100)를 제공하기 위한 방법 및 장치가 개시된다. 이동 멀티미디어 단말기(또는 MMT)(100)는 DVB-T와 같은 디지털 데이터 방송 수신기(102)를 이용한 광대역 데이터 스트림 수신을 허용한다. 상호작용성은 내장된 로컬 또는 대규모 셀 통신 링크(116 및 112)를 가지고 실현된다. 로컬 링크(112)는 WLAN 또는 블루투스(저-전력 RF 송수신기)일 수 있다. 대규모 셀 통신 링크(116)는 예를 들어, GSM, CDMA, TDMA 등과 같은 이동국 링크일 수 있다. 블루투스 링크를 가진 이동국은 아무런 로컬 접속점도 발견되지 않는 경우 대규모 셀 통신 링크들을 위한 IP 라우터 또는 휴대형 기지국으로서 사용될 수 있다. MMT(100)는 이동 환경에 상호작용성을 제공하기 위하여 DVB-T 수신, 디지털 디스플레이 및 통신 링크들을 함께 통합한다. 이동국을 가진 MMT 통신 링크는 이동 멀티미디어 단말기가 이동국을 위한 확장된 디스플레이 역할을 하도록 한다.',
#    'claim': {'claim1': {'content': '적어도, 대기를 통해 데이터 신호들을 수신하기 위하여 연결된 적어도 하나의 수신기, 상기 수신기의 기능들을 관리하고 조정하기 위하여 상기 수신기에 연결된 제어기, 디스플레이를 위하여 상기 대기를 통하여 수신된 데이터 신호들을 최적화하도록 미디어 디코더에 연결된 디스플레이 인터페이스,  및 상기 대기를 통하여 수신된 데이터 신호들에 대하여 상호작용하는 환경을 제공하기 위하여 상기 제어기에 연결된 저전력 무선 주파수 송수신기를 포함하는 이동 멀티미디어 단말기에서의 소비 전력을 감소시키는 방법에 있어서,상기 수신기를 비활성화하는 단계;서비스 정보에 따라 상기 수신기를 활성화하는 단계를 포함하는 것을 특징으로 하는 소비 전력 감소 방법.',
#      'independent': True},
#     'claim2': {'content': '상기 소비 전력 감소 방법은, 상기 수신기를 통해 수신된 데이터를 메모리 내에 저장하는 단계를 더 포함하는 것을 특징으로 하는 소비 전력 감소 방법.',
#      'independent': False},
#     'claim3': {'content': '상기 소비 전력 감소 방법은, 상기 저장된 데이터를 이용하여 내용을 표현하는 단계를 포함하는 것을 특징으로 하는 소비 전력 감소 방법.',
#      'independent': False},
#     'claim4': {'content': '방송 데이터를 수신하기 위한 수신기, 상기 수신된 데이터를 디코딩하기 위해 상기 상기 수신기에 연결된 미디어 디코더, 상기 수신기 및 상기 미디어 디코더의 기능들을 관리하고 조정하기 위해 상기 수신기 및 상기 미디어 디코더에 연결된 제어기를 포함하는 이동 멀티미디어에서의 데이터 수신 방법에 있어서,사용자가 방송 데이터를 수신하고자 원하는 시간에 상기 수신기를 활성화하는 단계;상기 수신기를 통해 데이터를 수신하는 단계; 및상기 수신된 데이터를 나중에 표현하기 위해 메모리 내에 저장하는 단계를 포함하는 것을 특징으로 하는 데이터 수신 방법.',
#      'independent': True},
#     'claim5': {'content': '상기 메모리는 버퍼인 것을 특징으로 하는 데이터 수신 방법.',
#      'independent': False},
#     'claim6': {'content': '상기 메모리는 저장 메모리인 것을 특징으로 하는 데이터 수신 방법.',
#      'independent': False},
#     'claim7': {'content': '상기 메모리는 메모리 카드인 것을 특징으로 하는 데이터 수신 방법.',
#      'independent': False}}},
#   'metadata': {'ipc': ['H04N 21/443', 'H04N 21/433'],
#    'priority': '미국',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=452306798ef1fd035bfb5ff666db4c9ce5214e757d798a128698ba0cdae2d3e28c688e911e44d8ff6f1637be657c6cd7'}},
#  {'id': '1020060018662',
#   'embed': {'name': '정보 교류 기능을 가진 단말기, 이를 이용한 정보 교류서버시스템 및 방법',
#    'abstract': ' 본 발명에 따른 단말기는 근거리 무선 통신을 통해 주변의 타 단말기 또는 서버와 정보를 교류할 수 있다. 또한 단말기 또는 서버는 자체에 데이터베이스를 구비하고 있어 타 단말기를 상대로 서비스 항목 정보를 교류 또는 GPS와 연계된 식별정보 등을 송수신할 수 있다. 본 발명의 특징적인 양상은 이 같은 단말기들이 주변의 타 단말기들의 식별정보, 위치정보와 같은 상황 정보를 직접 또는 서버로부터 수집하여 매 시각별로 저장함으로써 주변의 타 단말기 소지자들과 정보를 교류하거나 특정한 시각의 당시 주위 단말기 배치 상황을 조회할 수 있도록 할 수도 있다.단말기, GPS,식별정보 , 서비스 항목 정보, 상황도정보,송수신시각정보,전자 상거래정보,미팅정보, 도로공사정보,리서치정보, 금융정보, 역경매 정보, 공동구매정보, 긴급알림정보,지도정보, GIS,IBS,네비게이션,텔레메틱스,',
#    'claim': {'claim1': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 단말기로서,상기 다른 단말기와의 통신 기능을 수행하는 통신부;단말기의 식별정보를 포함한 정보를 저장하는 메모리;상기 통신부를 통해 상기 다른 단말기에 원하는 정보를 요청하고, 요청된 정보를 수신하여 해당 서비스를 수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim2': {'content': 'GPS 위성의 신호를 수신하여 위치 계산에 필요한 정보를 출력하는 GPS 모듈을 더 포함하며, 상기 제어부는 상기 다른 단말기들의 위치 정보를 입력받고, 입력받은 다른 단말기의 위치와 자신의 위치로부터 상황도 정보를 생성하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim3': {'content': '상기 제어부는,수신된 다른 단말기의 식별정보를 포함한 정보를 저장하는 주변 단말기 등록부와;외부로부터의 요구에 응답하여 상기 메모리에 저장된 주변 단말기들의 정보를 출력하는 주변 단말기 조회부를 포함하는 단말기.',
#      'independent': False},
#     'claim4': {'content': '상기 주변 단말기 등록부는 상기 타 단말기로부터 식별정보를 수신하여 상기 메모리에 저장함에 있어서 식별 정보, 수수시각 정보를 함께 저장하고, 상기 주변 단말기 조회부는 상기 메모리에 저장된 주변 단말기 정보를 출력함에 있어서 함께 저장된 식별 정보 수수 시각 별로 출력하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim5': {'content': '단말기에 충격이 가해지는 것을 감지하는 충격 감지 센서를 더 포함하며, 상기 제어부는 상기 충격 감지센서로부터 충격이 감지되면, 상기 통신부를 통해 미리 설정된 긴급 연락처로 접속하여 긴급상황을 알리는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim6': {'content': '상기 제어부는,자동차의 위치정보 및 주행 정보를 저장하는 도로 정보 처리 모듈을 더 포함하는 단말기.',
#      'independent': False},
#     'claim7': {'content': '상기 제어부가 수행하는 서비스는, 미팅신청, 전자상거래, 긴급상황, 도로공사, 리서치, 공동구매, 역경매, 금융중 적어도 하나를 포함하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim8': {'content': '주변의 다른 적어도 하나의 단말기 및 서버와 통신하며 정보를 교류하는 단말기로서,상기 다른 단말기 또는 상기 서버와의 통신 기능을 수행하는 통신부;단말기의 식별정보를 포함한 정보를 저장하는 메모리;상기 통신부를 통해 상기 서버에 상기 다른 단말기의 정보를 요청하고, 요청된 정보를 수신하여 해당 서비스를 수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim9': {'content': 'GPS 위성의 신호를 수신하여 위치 계산에 필요한 정보를 출력하는 GPS 모듈을 더 포함하며, 상기 제어부는 상기 서버로부터 자신과 다른 단말기들의 위치 정보가 나타난 상황도를 입력받고, 상기 서비스를 수행하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim10': {'content': '상기 제어부는 서비스가 미팅일 경우, 상기 상황도의 다른 단말기중 상대 단말기를 선택하여 미팅 제의 내용을 송신하고, 상대 단말기의 수락에 따라 정보를 송수신하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim11': {'content': '상기 제어부는 서비스가 도로공사 서비스일 경우, 상기 서버로부터 목적지 및 출발지에 관한 요금정보를 입력받아 결제하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim12': {'content': '주변의 다른 적어도 하나의 단말기 및 서버와 통신하며 정보를 교류하는 단말기로서,상기 다른 단말기 또는 상기 서버와의 통신 기능을 수행하는 통신부;단말기의 식별정보를 포함한 정보를 저장하는 메모리;사용자 단멀기 선택을 입력받는 입력부;상기 통신부를 통해 상기 다른 단말기에 필요한 정보를 요청하고, 요청된 정보를 수신하여 상기 입력부에서 선택되는 서비스를 수행하고, 그 결과를 상기 서버로 송신하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim13': {'content': '상기 제어부는 상기 서비스가 전자상거래일 경우 상기 다른 단말기로부터 상품정보를 입력받아 전자상거래를 수행한후 그 결과를 상기 서버로 송신하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim14': {'content': '상기 제어부는 상기 다른 단말기의 소정의 정보를 수신하기 위해 소정의 요금을 결제하는 것을 특징으로 하는 단말기.',
#      'independent': False},
#     'claim15': {'content': '적어도 하나의 제1 단말기와 통신하며, 정보를 교류하는 정보 교류 시스템으로서,제1 단말기를 포함하는 복수의 단말기 식별정보 및 그에 대응하는 서비스 정보를 저장하는 데이터베이스;상기 제1 단말기로부터 입력되는 서비스 요청 정보에 따라 그에 대응되는 서비스 정보를 상기 제1 단말기로 송신하는 서버를 포함하는 정보 교류 시스템.',
#      'independent': True},
#     'claim16': {'content': '상기 서버는 상기 제1 단말기가 긴급 상황임을 알리면, 상기 데이터베이스에 저장된 제1 단말기에 대응되는 긴급 연락처로 현재의 상황을 알리는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim17': {'content': '상기 서버는 상기 제1 단말기가 자신의 주변 상황에 대한 정보를 요청하면, 상기 제1 단말기와 제1 단말기로부터 소정의 거리에 위치한 단말기들의 위치 정보를 결합한 상황도 정보를 상기 제1 단말기 또는 외부에 위치한 적어도 하나의 정보기기로 송신하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim18': {'content': '상기 서버는 상기 제1 단말기가 전자 상거래 대상인 제2 단말기의  정보를 요청하면, 제2 단말기의 상품 관련 정보를 상기 제1 단말기에 송신하고, 주문시에 결제처리를 하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim19': {'content': '상기 서버는 상기 제1 단말기가 미팅 대상인 제2 단말기의  정보를 요청하면, 소정의 금액 결제후, 제2 단말기 소유자의 인적사항 정보를 상기 제1 단말기에 송신하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim20': {'content': '상기 서버는 상기 제1 단말기가 도로공사의 고속도로 요금 정보를 요청하면, 목적지 및 출발지에 따라 금액 정보를 제공하고, 금액 결제후 도로 공사 서버로 단말기 정보, 차량정보, 결제 정보, 목적지 및 출발지 정보를 송신하는 것을 특징으로 하는 정보 교류 시스템.',
#      'independent': False},
#     'claim21': {'content': '적어도 하나의 제1 단말기와 통신하며, 이동통신사 서버로부터 상기 제1 단말기를 포함한 단말기들의 위치 정보인 상황도 정보를 수신하여 정보를 교류하는 정보 교류 시스템으로서,제1 단말기를 포함하는 복수의 단말기 식별정보 및 그에 대응하는 서비스 정보를 저장하는 데이터베이스;상기 제1 단말기로부터 입력되는 서비스 요청 정보에 따라 그에 대응되는 서비스 정보 및 상기 상황도 정보를 상기 제1 단말기로 송신하는 서버를 포함하는 정보 교류 시스템.',
#      'independent': True},
#     'claim22': {'content': '데이터베이스 및 서버를 구비하고, 적어도 하나의 제1 단말기와 통신하며, 정보를 교류하는 정보 교류 방법으로서,상기 제1 단말기가 자신의 식별정보와 함께 서비스 요청 정보를 상기 서버로 송신하는 단계;상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계를 포함하는 정보 교류 방법.',
#      'independent': True},
#     'claim23': {'content': '상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계는, 상기 서버가 상기 식별정보에 포함된 상기 제1 단말기의 위치정보와 상기 제1 단말기로부터 소정의 거리에 위치한 단말기들의 위치 정보를 결합한 상황도 정보를 송신하는 단계를 포함하는 것을 특징으로 하는 정보 교류 방법.',
#      'independent': False},
#     'claim24': {'content': '상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기 제1 단말기로 송신하는 단계는, 서비스가 미팅일 경우, 상기 제1 단말기로부터 선택된 제2 단말기의 정보가 수신되면, 상기 서버가 상기 제2 단말기의 상세 정보를 상기 제1 단말기로 송신하는 단계를 더 포함하는 것을 특징으로 하는 정보 교류 방법.',
#      'independent': False},
#     'claim25': {'content': '상기 서비스 요청 정보에 따라 상기 서버가 상기 서비스에 대응하는 서비스 정보를 상기  제1단말기로 송신하는 단계는,상기 서비스가 도로공사 서비스일 경우, 상기 서버가 목적지 및 출발지에 관한 요금정보를 입력받아 결제하는 단계를 더 포함하는 것을 특징으로 하는 정보 교류 방법.',
#      'independent': False}}},
#   'metadata': {'ipc': ['G06F 15/16', 'G16C 10/00'],
#    'priority': '',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=452306798ef1fd035bfb5ff666db4c9cfe49d03e6a3dce0199755b97315cf9a7abd7f8c2bb2418ff80758b26a4b7438e'}},
#  {'id': '1020100103369',
#   'embed': {'name': '위치기반정보, 소셜 네트워크, 결제정보시스템 및 방법.',
#    'abstract': '',
#    'claim': {'claim1': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보  본문정보 본문결제정보 결제정보 금융 결제(어음, 당좌, 수표)정보 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하고 데이터베이스;상기 통신부를 통해 상기 단말기로부터 수신한 본문결제정보 본문정보 결제정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 정보 송신하고, 요청된 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 본문결제정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보, 광고정보 광고승인정보 공동구매정보 본문결제정보 결제선택정보 복권정보 기부정보 창업정보 게임정보 재화용역정보 부동산정보 펀드정보 인터넷서점정보 본문결제정보 인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보 수신하여 본문결제정보 제어하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim2': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 텔레뱅킹정보 인터넷뱅킹정보  금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보 본문정보 결제정보 본문결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷오환환전정보 단 본문정보를 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하고 데이터베이스;상기 통신부를 통해 상기 단말기로부터 본문결제할인정보를 중 어느 하나 이상 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보  본문정보  결제정보  금융 결제(어음, 당좌, 수표)정보 본문결제정보 복권정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보  송신하는 본문결제할인정보를  제어부가 포함하는 서버.',
#      'independent': True},
#     'claim3': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 텔레뱅킹정보 인터넷뱅킹정보  금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보 본문결제정보 결제선택정보 본문정보 결제정보 인터넷뱅킹정보  결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 인터넷외환환전정보 금융 결제(어음, 당좌, 수표)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷오환환전정보 단 본문정보를 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하고 데이터베이스;상기 통신부를 통해 상기 단말기로부터 본문결제할인정보를 중 어느 하나 이상 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보본문결제보험정보를  중 어느 하나 이상 정보 송신하여 해당 본문결제할인정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim4': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 텔레뱅킹정보 인터넷뱅킹정보  금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보 본문결제정보 결제선택정보 본문정보 결제정보 인터넷뱅킹정보  결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 인터넷외환환전정보 금융 결제(어음, 당좌, 수표)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷오환환전정보 단 본문정보를 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하고 데이터베이스;상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보 본문결제할인정보 결제선택정보 광고수신정보 할인정보 환급정보 결제선택정보  중 어느 하나 이상 포함되고 연계된 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 본문결제재화와 용역정보를 송신하여  본문결제할인정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim5': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보  본문정보 본문결제정보 결제정보 금융 결제(어음, 당좌, 수표)정보 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하고 데이터베이스;상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보 본문결제추가정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보  송신하고, 요청된 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 본문결제정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보, 광고정보 광고승인정보 공동구매정보 본문결제정보 결제선택정보 복권정보 기부정보 창업정보 게임정보 재화용역정보 부동산정보 펀드정보 인터넷서점정보 본문결제재화와 용역정보 인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보 수신하여, 본문결제추가정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim6': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보  본문정보 본문결제정보 결제정보 금융 결제(어음, 당좌, 수표)정보 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하고 데이터베이스;상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보 본문결제추가정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보  송신하고, 요청된 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 본문결제정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보, 광고정보 광고승인정보 공동구매정보 본문결제정보 결제선택정보 복권정보 기부정보 창업정보 게임정보 재화용역정보 부동산정보 펀드정보 인터넷서점정보 본문결제재화와 용역정보 인터넷뱅킹정보 텔레뱅킹정보 모바일 뱅킹정보 ATM금융정보 인터넷외환 환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보 수신하여, 본문결제추가정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버',
#      'independent': True},
#     'claim7': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 단말기로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 본문정보 본문결제정보 결제선택정보 금융 결제(어음, 당좌, 수표)정보 금융결제(수수료할인, 할인수수료, 할인, 선부가세, 추가)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하는 메모리; 상기 통신부를 통해 상기 서버로 광고정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보  본문정보 본문결제정보 결제정보 금융 계좌정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 본문결제정보  본문결제보험정보를 중 어느 하나 이상 포함되고 연계된 정보  송신하고, 요청된 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 본문결제정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보, 광고정보 광고승인정보 공동구매정보 본문결제정보 결제선택정보 복권정보 기부정보 창업정보 게임정보 재화용역정보 부동산정보 펀드정보 인터넷서점정보 본문결제보험정보를 수신하여 해당 본문결제보험정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 결제선택정보 본문정보 금융 결제(어음, 당좌, 수표)정보 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim8': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 단말기로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 본문정보 본문결제정보 결제선택정보 금융 결제(어음, 당좌, 수표)정보 금융결제(수수료할인, 할인수수료, 할인, 선부가세, 추가)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하는 메모리; 상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보  본문결제복권정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보  송신하고, 요청된 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 본문결제정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보, 광고정보 광고승인정보 공동구매정보 본문결제정보 결제선택정보 복권정보 기부정보 창업정보 게임정보 재화용역정보 부동산정보 펀드정보 인터넷서점정보 본문결제복권정보를 수신하여 본문결제복권정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 결제선택정보 본문정보 금융 결제(어음, 당좌, 수표)정보 광고정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim9': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 단말기로,상기 다른 단말기와의 결제정보 결제선택정보 할인정보 환급정보 세금정보 중 어느 하나 이상 포함되고 연계된 정보 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보  본문정보 본문결제정보 결제선택정보 금융 결제(어음, 당좌, 수표)정보 금융결제(수수료할인, 할인수수료, 할인, 선부가세, 추가)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하는 메모리;상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보 금융 결제(어음, 당좌, 수표)정보 광고정보 본문결제정보 광고수신정보 할인정보 환급정보 결제선택정보  중 어느 하나 이상 포함되고 연계된 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보정보 본문결제정보 송신하여 본문결제정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부를 포함하는  단말기.',
#      'independent': True},
#     'claim10': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 단말기로,상기 다른 단말기와 서버 결제선택정보 금융 결제(어음, 당좌, 수표)정보 금융결제 텔레뱅킹 모바일뱅킹 ATM뱅킹 인터넷외화환전정보 본문결제정보 본문정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 본문정보 본문결제정보 결제선택정보 금융 결제(어음, 당좌, 수표)정보 금융결제(수수료할인, 할인수수료, 할인, 선부가세, 추가)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하는 메모리; 상기 통신부를 통해 상기 중계단말기로부터 본문결제재화와 용역정보 광고수신정보 할인정보 환급정보 결제선택정보  중 어느 하나 이상 포함되고 연계된 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보결제재화와 용역정보를 송신하는 본문결제정보를  수행하는 제어부를 포함하는 단말기.',
#      'independent': True},
#     'claim11': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 결제선택정보 금융 결제(어음, 당좌, 수표)정보 광고정보 본문정보 본문결제정보 광고수신승인정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하는 데이터베이스;상기 통신부를 통해 상기 단말기로 결제할인정보 본문결제정보 인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융 인터넷외환화전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 분류자동저장정보 이메일자동분류정보 분류검색자동저장정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 정보 송신하고 요청된 본문결제보험정보를 스크랩분류자동저장정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 정보 수신하고,해당 결제할인정보를  수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim12': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와 서버 결제선택정보 금융 결제(어음, 당좌, 수표)정보 금융결제 텔레뱅킹 모바일뱅킹 ATM뱅킹 인터넷외화환전정보 본문결제정보 본문정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 본문정보 본문결제정보 결제선택정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보를 저장하는 데이터베이스;상기 통신부를 통해 상기 단말기로부터 결제할인정보를 중 어느 하나 이상 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보본문결제보험정보를  중 어느 하나 이상 정보 송신하고, 해당 결제할인정보를  수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim13': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 텔레뱅킹정보 인터넷뱅킹정보  금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보 본문결제정보 결제선택정보 본문정보 결제정보 인터넷뱅킹정보  결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 인터넷외환환전정보 금융 결제(어음, 당좌, 수표)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 본문정보 본문결제정보 결제선택정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보를 저장하는 데이터베이스;상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보  결제할인정보를 중 어느 하나 이상 포함되고 연계된 정보  송신하고, 요청된 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 본문결제정보 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보, 광고정보 광고승인정보 공동구매정보 본문결제정보 결제선택정보 복권정보 기부정보 창업정보 게임정보 재화용역정보 부동산정보 펀드정보 인터넷서점정보 본문결제보험정보를 수신하여 해당 결제할인정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim14': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 텔레뱅킹정보 인터넷뱅킹정보  금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보 본문결제정보 결제선택정보 본문정보 결제정보 인터넷뱅킹정보  결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 인터넷외환환전정보 금융 결제(어음, 당좌, 수표)정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 본문정보 본문결제정보 결제선택정보 광고정보 광고수신승인정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 송수신시각정보 스크랩분류정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보 중 어느 하나 이상 포함되고 연계된 정보를 저장하는 데이터베이스;상기 통신부를 통해 상기 외부서버로 인터넷외환환전정보 본문결제정보 결제정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환환전수수료정보 RFID결제정보 바코드결제정보 광고정보 광고수신승인정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 모바일뱅킹정보 ATM뱅킹정보 부터  결제할인정보 광고수신정보 할인정보 환급정보 결제선택정보  중 어느 하나 이상 포함되고 연계된 정보 수신하고, 요청된 결제선택정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 인터넷 외환 환전수수료정보 본문결제정보 금융 계좌정보 게임정보 광고정보 광고수신승인정보  인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보, SNS정보, 다수의사업자정보, 다수의 분류정보, 다수의 직급정보, 동영상정보, 스크랩자동분류정보  인터넷뱅킹정보 텔레뱅킹정보 모바일뱅킹정보 ATM금융정보 본문결제보험정보를 송신하여  결제할인정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버.',
#      'independent': True},
#     'claim15': {'content': '주변의 다른 적어도 하나의 단말기와 통신하며 정보를 교류하는 서버로,상기 다른 단말기와의 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의분류정보, RFID정보, 동영상정보, 광고정보 광고수신승인정보 금융 결제(어음, 당좌, 수표)정보 금리인하할인 본문결제정보 텔레뱅킹 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융정보 인터넷외환환전정보  본문정보 결제선택정보 결제정보 인터넷뱅킹정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보를 통신기능을 수행하는 통신부;단말기의 식별정보를 포함한 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩분류저장정보  SNS정보, 다수의 사업자정보, 다수의 분류정보, 다수의 직급정보, RFID정보, ATM금융거래정보 인터넷외환환전정보 결제선택정보 금융 결제(어음, 당좌, 수표)정보 광고정보 본문정보 본문결제정보 광고수신승인정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 저장하는 데이터베이스;상기 통신부를 통해 상기 중계단말기로부터 결제할인정보 수신하고, 요청된 본문결제보험정보를  중 어느 하나 이상 정보 송신하고, 해당 결제할인정보 본문결제정보 본문정보 인터넷뱅킹정보 결제증권정보 결제외환 선물정보 결제증권수수료정보 결제외환수수료정보 송금수수료정보 결제정보 할인정보 환급정보 결제선택정보 보험정보 구인구직정보 복권정보 기부정보 창업정보 펀드정보 게임정보 예금정보 재화 용역정보 이체수수료정보 외환환전수수료정보  할인정보 환급정보 선부가세정보 추가정보 텔레뱅킹정보 금융 결제(정상, 할인, 부가세, 세금, 환급, 추가)정보 금융 결제(어음, 당좌, 수표)정보 모바일뱅킹 ATM금융 인터넷외환환전정보 분류저장정보 결제증권정보 결제증권수수료정보 결제외환 선물정보 결제외환수수료정보 분류검색정보 스크랩 자동분류정보 금융 결제(어음, 당좌, 수표)정보 결제정보 결제선택정보 결제정보 할인정보 환급정보(결제정보, 직접세정보, 간접세정보, 금융수수료정보, 세금정보, 부가세정보) 중 어느 하나 이상 포함되고 연계된 정보 중 하나 이상 포함되고 연계된 정보 수행하는 제어부 포함하는 서버.',
#      'independent': True},
# ...
#      'independent': False},
#     'claim9': {'content': '상기 제1 및 제2 커버층은 광 경화성 폴리 이미드를 포함하는 전자 장치.',
#      'independent': False},
#     'claim10': {'content': '상기 베이스층, 상기 제1 및 제2 커버층 각각은 광 경화성 폴리 이미드를 포함하는 전자 장치.',
#      'independent': False},
#     'claim11': {'content': '상기 제2 점착층은 상기 제1 및 제2 서브 점착층을 포함하고,상기 제1 및 제2 서브 점착층 사이의 이격 공간은 상기 폴딩 영역과 중첩하고, 상기 제1 및 제2 서브 점착층 사이의 이격 공간에 의해 상기 디지타이저와 상기 플레이트 사이에는 제3 공극이 제공되는 전자 장치.',
#      'independent': False},
#     'claim12': {'content': '상기 제1 점착층은 서로 이격되어 배치된 제3 및 제4 서브 점착층을 포함하고,상기 제3 및 제4 서브 점착층 사이의 이격 공간은 상기 폴딩 영역과 중첩하며, 상기 제3 및 제4 서브 점착층 사이의 이격 공간에 의해 상기 표시 모듈과 상기 디지타이저 사이에는 제4 공극이 제공되는 전자 장치.',
#      'independent': False},
#     'claim13': {'content': '상기 플레이트는,상기 폴딩 영역과 중첩하는 복수의 개구 패턴들이 제공된 벤딩부를 포함하는 전자 장치.',
#      'independent': False},
#     'claim14': {'content': '상기 표시 모듈과 상기 제1 점착층 사이에 배치된 보호층을 더 포함하는 전자 장치.',
#      'independent': False},
#     'claim15': {'content': '상기 제1 및 제2 점착층 각각은 -20℃에서 0.01 MPa 이상 0.2 MPa 이하의 탄성률을 갖는 전자 장치.',
#      'independent': False},
#     'claim16': {'content': '상기 제1 및 제2 점착층 각각은 20㎛ 이하의 두께를 갖는 전자 장치.',
#      'independent': False},
#     'claim17': {'content': '제1 비폴딩 영역, 제2 비폴딩 영역 및 폴딩 영역이 정의되고, 플랫한 제1 상태 또는 상기 제1 및 제2 비폴딩 영역이 마주하도록 폴딩된 제2 상태를 갖는 표시 모듈;상기 표시 모듈 상에 배치된 윈도우;상기 표시 모듈의 하측에 배치되고, 상기 폴딩 영역과 중첩하는 벤딩부를 포함하는 플레이트;상기 플레이트와 상기 표시 모듈 사이에 배치된 디지타이저;상기 표시 모듈과 상기 디지타이저 사이에 배치된 제1 점착층; 및상기 디지타이저와 상기 플레이트 사이에 배치된 제2 점착층을 포함하고,상기 제1 및 제2 점착층 중 적어도 하나는 상기 폴딩 영역에 대응하여 이격하여 배치된 제1 및 제2 서브 점착층을 포함하는 전자 장치.',
#      'independent': True},
#     'claim18': {'content': '상기 디지타이저는,복수의 제1 감지 배선;복수의 제1 감지 배선과 절연되게 교차하는 복수의 제2 감지 배선; 및상기 복수의 제1 감지 배선들 사이에 배치된 제1 더미 배선; 및상기 복수의 제2 감지 배선들 사이에 배치된 제2 더미 배선을 포함하는 표시장치.',
#      'independent': False},
#     'claim19': {'content': '상기 제1 및 제2 더미 배선들은 상기 폴딩 영역과 중첩하지 않는 표시장치.',
#      'independent': False},
#     'claim20': {'content': '상기 윈도우는 80㎛ 이하의 두께를 갖는 박막 글라스를 포함하는 전자 장치.',
#      'independent': False}}},
#   'metadata': {'ipc': ['G06F 1/16',
#     'C09J 9/00',
#     'G06F 3/041',
#     'G09F 9/30',
#     'H04M 1/02'],
#    'priority': '',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=6c650beb4cee9ce4122b704b88878c93e078faf6e4861a43d857ab91a0013950965d4101129c48c051e5a8b6d8cd953ca1b76d772aad4cded1039496ed2fbf1ebcd20adf739dd21d'}},
#  {'id': '1020200122188',
#   'embed': {'name': '기판 검사 장치 및 이의 검사 방법',
#    'abstract': ' 실시 예에 따른 기판 검사 장치는 검사 대상물에 대한 제품 도면 이미지를 저장하는 저장부; 상기 검사 대상물을 촬영한 제1 이미지를 획득하는 이미지 획득부; 상기 제품 도면 이미지에서, 상기 제1 이미지에 대응하는 제1 영역을 검출하는 프로세서; 상기 제1 이미지의 해상도를 기준으로, 상기 프로세서를 통해 검출된 제1 영역의 이미지를 스케일링하여 제2 이미지를 생성하는 이미지 스케일러; 상기 제1 이미지 및 상기 제2 이미지를 합성한 제3 이미지를 생성하는 이미지 합성부; 및 상기 제3 이미지를 이용하여, 상기 검사 대상물의 불량 여부를 판단하기 위한 학습을 진행하고, 상기 학습 진행 결과를 기반으로 상기 검사 대상물의 불량 여부에 대한 검사를 진행하는 학습 및 검사부;를 포함한다. ',
#    'claim': {'claim1': {'content': '검사 대상물에 대한 제품 도면 이미지를 저장하는 저장부;상기 검사 대상물을 촬영한 제1 이미지를 획득하는 이미지 획득부;상기 제품 도면 이미지에서, 상기 제1 이미지에 대응하는 제1 영역을 검출하는 프로세서;상기 제1 이미지의 해상도를 기준으로, 상기 프로세서를 통해 검출된 제1 영역의 이미지를 스케일링하여 제2 이미지를 생성하는 이미지 스케일러;상기 제1 이미지 및 상기 제2 이미지를 합성한 제3 이미지를 생성하는 이미지 합성부; 및상기 제3 이미지를 이용하여, 상기 검사 대상물의 불량 여부를 판단하기 위한 학습을 진행하고, 상기 학습 진행 결과를 기반으로 상기 검사 대상물의 불량 여부에 대한 검사를 진행하는 학습 및 검사부;를 포함하는,기판 검사 장치.',
#      'independent': True},
#     'claim2': {'content': '상기 제1 이미지는, 학습 모드에서 불량 유형별로 획득된 제1-1 이미지를 포함하고,상기 제3 이미지는 상기 제1-1 이미지와 상기 제2 이미지를 합성한 제3-1 이미지를 포함하는,기판 검사 장치.',
#      'independent': False},
#     'claim3': {'content': '상기 제1 이미지는, 검사 모드에서 상기 검사 대상물의 특정 영역을 촬영한 제1-2 이미지를 포함하고,상기 제3 이미지는 상기 제1-2 이미지와 상기 제2 이미지를 합성한 제3-2 이미지를 포함하는,기판 검사 장치.',
#      'independent': False},
#     'claim4': {'content': '상기 영상 합성부는,상기 제1 이미지 위에, 상기 제2 이미지에 포함된 형상적 정보를 오버랩하여 상기 제3 이미지를 생성하고,상기 형상적 정보는,상기 검사 대상물에 포함된 패턴의 형상 정보를 포함하는,기판 검사 장치.',
#      'independent': False},
#     'claim5': {'content': '상기 학습 및 검사부는 딥 러닝 방식을 통해 학습 및 검사를 수행하는,기판 검사 장치.',
#      'independent': False},
#     'claim6': {'content': '상기 영상 합성부는,상기 제1 및 제2 이미지에서 패턴 영역 및 비패턴 영역을 분리하고, 상기 분리된 영역별로 서로 다른 이미지 처리 파라미터를 적용하여 상기 제3 이미지를 생성하는,기판 검사 장치.',
#      'independent': False},
#     'claim7': {'content': '상기 프로세서는 상기 획득된 제1-2 이미지를 사전 검사하고,상기 사전 검사 결과, 상기 제1-2 이미지가 치명 불량 영역을 포함하는 경우, 상기 제1-2 이미지를 상기 학습 및 검사부에 제공하지 않고 불량으로 판단하는,기판 검사 장치.',
#      'independent': False},
#     'claim8': {'content': '상기 치명 불량 영역은, 패턴 오픈 영역 또는 패턴 쇼트 영역을 포함하는,기판 검사 장치.',
#      'independent': False},
#     'claim9': {'content': '상기 프로세서는,상기 제1 이미지의 픽셀별 영상 정보 및 상기 제2 이미지의 픽셀별 영상 정보를 비교하고,상기 비교 결과에 따라, 상기 오버랩을 위한 매칭 픽셀에 대한 좌표 정보를 획득하며,상기 획득한 좌표 정보를 기반으로 상기 제3 이미지가 생성되도록 상기 이미지 합성부를 제어하는,기판 검사 장치.',
#      'independent': False},
#     'claim10': {'content': '검사 대상물을 촬영하여 제1 이미지를 획득하고,제품 도면 이미지에서, 상기 제1 이미지에 대응하는 제1 영역을 검출하고,상기 제1 이미지의 해상도를 기준으로, 상기 프로세서를 통해 검출된 제1 영역의 이미지를 스케일링하여 제2 이미지를 생성하고,상기 제1 이미지 및 상기 제2 이미지를 합성하여 제3 이미지를 생성하며,상기 제3 이미지를 이용하여, 상기 검사 대상물의 불량 여부를 판단하기 위한 학습 및 상기 학습에 대한 결과를 기반으로 상기 검사 대상물의 불량 여부에 대한 검사를 진행하는 것을 포함하는,기판 검사 방법.',
#      'independent': True},
#     'claim11': {'content': '상기 제1 이미지는, 학습 모드에서 불량 유형별로 획득된 제1-1 이미지를 포함하고,상기 제3 이미지는 상기 제1-1 이미지와 상기 제2 이미지를 합성한 제3-1 이미지를 포함하는,기판 검사 방법.',
#      'independent': False},
#     'claim12': {'content': '상기 제1 이미지는, 검사 모드에서 상기 검사 대상물의 특정 영역을 촬영한 제1-2 이미지를 포함하고,상기 제3 이미지는 상기 제1-2 이미지와 상기 제2 이미지를 합성한 제3-2 이미지를 포함하는,기판 검사 방법.',
#      'independent': False},
#     'claim13': {'content': '상기 제3 이미지를 생성하는 것은,상기 제1 이미지 위에, 상기 제2 이미지에 포함된 형상적 정보를 오버랩하여 상기 제3 이미지를 생성하는 것을 포함하고,상기 형상적 정보는,상기 검사 대상물에 포함된 패턴의 형상 정보를 포함하는,기판 검사 방법.',
#      'independent': False},
#     'claim14': {'content': '상기 학습 및 검사는 딥 러닝 방식을 통해 수행하는,기판 검사 방법.',
#      'independent': False},
#     'claim15': {'content': '상기 제3 이미지를 생성하는 것은,상기 제1 및 제2 이미지에서 패턴 영역 및 비패턴 영역을 분리하고, 상기 분리된 영역별로 서로 다른 이미지 처리 파라미터를 적용하여 상기 제3 이미지를 생성하는 것을 포함하는,기판 검사 방법.',
#      'independent': False},
#     'claim16': {'content': '상기 획득된 제1-2 이미지를 사전 검사하고,상기 사전 검사 결과, 상기 제1-2 이미지가 치명 불량 영역을 포함하는 경우, 상기 제1-2 이미지에 대하여 상기 학습 결과에 기반한 검사 과정 없이 불량으로 판단하는 것을 포함하는,기판 검사 방법.',
#      'independent': False},
#     'claim17': {'content': '상기 치명 불량 영역은, 패턴 오픈 영역 또는 패턴 쇼트 영역을 포함하는,기판 검사 방법.',
#      'independent': False},
#     'claim18': {'content': '상기 제3 이미지를 생성하는 것은,상기 제1 이미지의 픽셀별 영상 정보 및 상기 제2 이미지의 픽셀별 영상 정보를 비교하고,상기 비교 결과에 따라, 상기 오버랩을 위한 매칭 픽셀에 대한 좌표 정보를 획득하며,상기 획득한 좌표 정보를 기반으로 상기 제1 및 제2 이미지를 합성하여 상기 제3 이미지가 생성하는 것을 포함하는,기판 검사 방법.',
#      'independent': False}}},
#   'metadata': {'ipc': ['G01N 21/956',
#     'G01N 21/88',
#     'G06T 7/00',
#     'G06T 7/00',
#     'G06N 3/08',
#     'G01N 21/88',
#     'G01N 21/88',
#     'G01N 21/956'],
#    'priority': '',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=6c650beb4cee9ce4122b704b88878c93221179325cbd088b6fed417773d2e5a9c202b0a7f869627d45b6a7e9ed9e30c4d7c39b82e9852a8ae4e26d86e58269b18a31a96834644d4e'}},
#  {'id': '1020200122210',
#   'embed': {'name': '반도체 장치 및 반도체 장치의 제조 방법',
#    'abstract': ' 반도체 장치는, 교대로 적층된 제1 도전막들 및 절연막들을 포함하는 적층물; 상기 적층물 상에 위치된 제2 도전막들; 상기 제2 도전막들 및 상기 적층물을 관통하고 제1 폭을 갖는 제1 개구부들; 상기 제1 개구부들 내에 형성되고, 상기 적층물 상에 위치되어 상기 제2 도전막들과 전기적으로 연결된 제2 도전 패턴들; 상기 제1 개구부들 내에 형성되고, 상기 제2 도전 패턴들의 하부에 위치된 데이터 저장 패턴들; 및 상기 데이터 저장 패턴들 및 상기 제2 도전 패턴들 내에 형성된 채널막들을 포함할 수 있다. ',
#    'claim': {'claim1': {'content': '교대로 적층된 제1 도전막들 및 절연막들을 포함하는 적층물;상기 적층물 상에 위치된 제2 도전막들;상기 제2 도전막들 및 상기 적층물을 관통하고 제1 폭을 갖는 제1 개구부들;상기 제1 개구부들 내에 형성되고, 상기 적층물 상에 위치되어 상기 제2 도전막들과 전기적으로 연결된 제2 도전 패턴들;상기 제1 개구부들 내에 형성되고, 상기 제2 도전 패턴들의 하부에 위치된 데이터 저장 패턴들; 및상기 데이터 저장 패턴들 및 상기 제2 도전 패턴들 내에 형성된 채널막들을 포함하는 반도체 장치.',
#      'independent': True},
#     'claim2': {'content': '상기 적층물 상에 위치되고 상기 제2 도전막들의 사이에 개재된 분리 절연 패턴을 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim3': {'content': '상기 제2 도전 패턴들 중 적어도 하나의 제2 도전 패턴은 상기 분리 절연 패턴과 접하는반도체 장치.',
#      'independent': False},
#     'claim4': {'content': '상기 제2 도전막들 상에 형성된 층간 절연막을 더 포함하고,상기 분리 절연 패턴과 상기 층간 절연막은 단일막으로 연결된반도체 장치.',
#      'independent': False},
#     'claim5': {'content': '상기 채널막들과 상기 데이터 저장 패턴들의 사이 및 상기 채널막들과 상기 제2 도전 패턴들의 사이에 개재된 터널 절연막들을 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim6': {'content': '상기 제2 도전 패턴들은 상기 채널막들과 상기 제2 도전막들의 사이에 개재된반도체 장치.',
#      'independent': False},
#     'claim7': {'content': '상기 채널막들과 각각 연결되고, 상기 제2 도전막들의 상부면에 비해 돌출된 채널 패드들; 및상기 채널 패드들을 감싸는 절연성 보호막을 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim8': {'content': '상기 제1 개구부들의 사이에서 상기 적층물을 관통하고, 상기 제2 도전막들의 사이로 확장된 슬릿 구조를 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim9': {'content': '상기 슬릿 구조는, 소스 콘택 구조; 및상기 소스 콘택 구조의 측벽을 감싸는 절연 스페이서를 포함하는 반도체 장치.',
#      'independent': False},
#     'claim10': {'content': '교대로 적층된 워드 라인들 및 절연막들을 포함하고, 상기 워드 라인들은 제1 폭의 제1 개구부들을 포함하는 적층물;상기 적층물 상에 위치되고, 상기 제1 폭보다 좁은 제2 폭의 제2 개구부들을 포함하는 선택 라인들;상기 적층물 상에 위치되고, 상기 선택 라인들을 상호 절연시키는 분리 절연 패턴;상기 제1 개구부들 내에 형성되고, 상기 선택 라인들의 하부에 위치된 데이터 저장 패턴들; 및상기 데이터 저장 패턴들 내에 형성되고, 상기 제2 개구부까지 확장된 채널막들을 포함하는 반도체 장치.',
#      'independent': True},
#     'claim11': {'content': '상기 선택 라인들 각각은,상기 채널막들의 측벽을 공통으로 감싸는 도전막;상기 채널막들의 측벽을 각각 감싸고 상기 채널막들과 상기 도전막의 사이에 개재된 도전 패턴들을 포함하는반도체 장치.',
#      'independent': False},
#     'claim12': {'content': '상기 도전 패턴들은 상기 도전막과 동일하거나 상이한 물질을 포함하는반도체 장치.',
#      'independent': False},
#     'claim13': {'content': '상기 도전 패턴들 중 적어도 하나의 도전 패턴은 상기 분리 절연 패턴과 접하는반도체 장치.',
#      'independent': False},
#     'claim14': {'content': '상기 채널막들과 상기 데이터 저장 패턴들의 사이 및 상기 채널막들과 상기 선택 라인들의 사이에 개재된 터널 절연막들을 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim15': {'content': '상기 채널막들과 각각 연결되고, 상기 선택 라인들의 상부면에 비해 돌출된 채널 패드들; 및상기 채널 패드들을 감싸는 절연성 보호막을 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim16': {'content': '상기 제1 개구부들의 사이에서 상기 적층물을 관통하고, 상기 선택 라인들의 사이로 확장된 슬릿 구조를 더 포함하는 반도체 장치.',
#      'independent': False},
#     'claim17': {'content': '상기 슬릿 구조는, 소스 콘택 구조; 및상기 소스 콘택 구조의 측벽을 감싸는 절연 스페이서를 포함하는 반도체 장치.',
#      'independent': False},
#     'claim18': {'content': '제1 물질막들 및 제2 물질막들이 교대로 적층된 적층물을 형성하는 단계;상기 적층물 상에 도전막을 형성하는 단계;상기 도전막 상에 희생막을 형성하는 단계;상기 희생막, 상기 도전막 및 상기 적층물을 관통하는 제1 개구부를 형성하는 단계;상기 제1 개구부 내에 데이터 저장막을 형성하는 단계;상기 데이터 저장막 내에 채널 구조를 형성하는 단계;상기 도전막으로부터 상기 채널 구조가 돌출되도록 상기 희생막을 제거하는 단계;상기 데이터 저장막을 식각하여 상기 채널 구조와 상기 도전막의 사이에 개재된 제2 개구부를 형성하는 단계;상기 제2 개구부 내에 도전 패턴을 형성하는 단계; 및상기 도전 라인을 관통하는 분리 절연 패턴을 형성하는 단계를 포함하는 반도체 장치의 제조 방법.',
#      'independent': True},
#     'claim19': {'content': '상기 채널 구조를 형성하는 단계는,상기 제1 개구부 내에 채널막을 형성하는 단계;상기 채널막 내에 절연 코어를 형성하는 단계; 및상기 제1 개구부 내에 상기 채널막과 연결된 채널 패드를 형성하는 단계를 포함하는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim20': {'content': '상기 희생막을 제거하여 상기 도전막으로부터 상기 채널 패드를 돌출시키는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim21': {'content': '상기 채널 구조를 형성하기 전에, 상기 데이터 저장막 내에 터널 절연막을 형성하는 단계를 더 포함하는 반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim22': {'content': '상기 도전 패턴은 상기 터널 절연막과 상기 도전막의 사이에 형성되는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim23': {'content': '상기 데이터 저장막을 형성하기 전에, 블로킹막을 형성하는 단계를 더 포함하고,상기 블로킹막을 식각한 후에 상기 데이터 터장막을 식각하여 상기 제2 개구부를 형성하는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim24': {'content': '상기 도전 패턴을 형성하는 단계는,상기 제2 개구들 내에 형성된 제1 부분 및 돌출된 상기 채널 구조를 감싸는 제2 부분을 포함하는 도전 물질막을 형성하는 단계; 및상기 도전 물질막 중 상기 제2 부분을 식각하여 상기 도전 패턴을 형성하는 단계를 포함하는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim25': {'content': '상기 도전 패턴을 형성한 후, 돌출된 상기 채널 구조를 감싸는 절연성 보호막을 형성하는 단계를 더 포함하는 반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim26': {'content': '상기 분리 절연 패턴을 형성하는 단계는,상기 도전막 및 돌출된 상기 채널 구조 상에 스페이서 물질막을 형성하는 단계;상기 스페이서 물질막 상에 마스크 패턴을 형성하는 단계;상기 마스크 패턴을 식각 배리어로 상기 스페이서 물질막을 식각하여 상기 돌출된 채널 구조의 측벽에 스페이서를 형성하는 단계;상기 마스크 패턴 및 상기 스페이서를 식각 배리어로 상기 도전막을 식각하여 제3 개구부를 형성하는 단계; 및상기 제3 개구부 내에 상기 분리 절연 패턴을 형성하는 단계를 포함하는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim27': {'content': '상기 스페이서 물질막은 비정질 탄소를 포함하는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim28': {'content': '상기 스페이서 물질막을 형성하는 단계는,스텝 커버리지가 나쁜 증착 공정을 이용하여 상기 스페이서 물질막을 형성하는반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim29': {'content': '상기 마스크 패턴 및 상기 스페이서들을 식각 배리어로 상기 도전막 및 상기 적층물을 식각하여 제4 개구부를 형성하는 단계; 및상기 제4 개구부 내에 슬릿 구조를 형성하는 단계를 더 포함하는 반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim30': {'content': '상기 제4 개구부들을 통해 상기 제1 물질막들을 제거하여 제5 개구부들을 형성하는 단계; 및상기 제5 개구부들 내에 제3 물질막들을 형성하는 단계를 더 포함하는 반도체 장치의 제조 방법.',
#      'independent': False},
#     'claim31': {'content': '상기 슬릿 구조를 형성하는 단계는,상기 제4 개구부 내에 절연 스페이서를 형성하는 단계; 및상기 절연 스페이서 내에 소스 콘택 구조를 형성하는 단계를 포함하는반도체 장치의 제조 방법.',
#      'independent': False}}},
#   'metadata': {'ipc': ['H10B 41/27',
#     'H10B 41/35',
#     'H10B 43/35',
#     'H10B 43/27',
#     'H01L 21/768'],
#    'priority': '',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=6c650beb4cee9ce4122b704b88878c93221179325cbd088b6fed417773d2e5a9c202b0a7f869627d17088b55ec2209e81a408f90ba4cd6a4b646992cd9741285b44ed06ebcabbe59'}},
#  {'id': '1020200122252',
#   'embed': {'name': '표시 장치, 인증 방법, 및 프로그램',
#    'abstract': ' 본 발명은 터치 검출 기능과 지문의 촬상 기능을 겸비한 표시 장치를 제공한다. 표시 장치는 발광 소자, 수광 소자, 제 1 도전층, 제 2 도전층, 및 절연층을 가지는 구성으로 한다. 발광 소자는 제 1 화소 전극, 발광층, 공통 전극을 가지고, 수광 소자는 제 2 화소 전극, 활성층, 공통 전극을 가진다. 제 1 화소 전극과 제 2 화소 전극은 동일면 위에 제공된다. 공통 전극은 발광층을 개재하여 제 1 화소 전극과 중첩되는 부분 및 발광층을 개재하여 제 2 화소 전극과 중첩되는 부분을 가진다. 제 1 도전층, 제 2 도전층, 및 절연층은 공통 전극 위쪽에 제공되고, 절연층은 제 1 도전층 위쪽에 제공되고, 제 2 도전층은 절연층 위쪽에 제공된다. 또한 수광 소자는 발광 소자가 방출하는 광을 수광하는 기능을 가진다. ',
#    'claim': {'claim1': {'content': '표시 장치로서,발광 소자;수광 소자;제 1 도전층;제 2 도전층; 및절연층을 포함하고,상기 발광 소자는 제 1 화소 전극, 발광층, 및 공통 전극을 포함하고,상기 수광 소자는 제 2 화소 전극, 활성층, 및 상기 공통 전극을 포함하고,상기 제 1 화소 전극 및 상기 제 2 화소 전극은 동일면 위에 있고,상기 공통 전극은 상기 발광층을 개재하여 상기 제 1 화소 전극과 중첩되는 부분 및 상기 활성층을 개재하여 상기 제 2 화소 전극과 중첩되는 부분을 포함하고,상기 제 1 도전층, 상기 제 2 도전층, 및 상기 절연층은 상기 공통 전극 위쪽에 있고,상기 절연층은 상기 제 1 도전층 위쪽에 있고,상기 제 2 도전층은 상기 절연층 위쪽에 있고,상기 수광 소자는 상기 발광 소자로부터 방출되는 광을 수광하는 기능을 가지는, 표시 장치.',
#      'independent': True},
#     'claim2': {'content': '상기 제 1 도전층은 복수의 개구를 포함하고,상기 발광 소자는 상기 제 1 도전층의 상기 개구 중 하나와 중첩되고,상기 수광 소자는 상기 제 1 도전층의 상기 개구 중 다른 하나와 중첩되는, 표시 장치.',
#      'independent': False},
#     'claim3': {'content': '공통층을 더 포함하고,상기 공통층은 상기 제 1 화소 전극과 상기 공통 전극 사이의 부분 및 상기 제 2 화소 전극과 상기 공통 전극 사이의 부분을 포함하고,상기 발광층과 상기 활성층은 상이한 유기 화합물을 포함하는, 표시 장치.',
#      'independent': False},
#     'claim4': {'content': '표시 장치로서,발광 소자;수광 소자;제 1 도전층;제 2 도전층;절연층; 및보호층을 포함하고,상기 발광 소자는 제 1 화소 전극, 발광층, 및 공통 전극을 포함하고,상기 수광 소자는 제 2 화소 전극, 활성층, 및 상기 공통 전극을 포함하고,상기 제 1 화소 전극 및 상기 제 2 화소 전극은 동일면 위에 있고,상기 공통 전극은 상기 발광층을 개재하여 상기 제 1 화소 전극과 중첩되는 부분 및 상기 활성층을 개재하여 상기 제 2 화소 전극과 중첩되는 부분을 포함하고,상기 보호층은 상기 공통 전극 위쪽에 있고,상기 제 1 도전층은 상기 보호층의 위쪽에 있고,상기 절연층은 상기 제 1 도전층 및 상기 보호층 위쪽에 있고,상기 제 2 도전층은 상기 절연층 위쪽에 있고,상기 수광 소자는 상기 발광 소자로부터 방출되는 광을 수광하는 기능을 가지는, 표시 장치.',
#      'independent': True},
#     'claim5': {'content': '상기 제 1 도전층은 복수의 개구를 포함하고,상기 발광 소자는 상기 제 1 도전층의 상기 개구 중 하나와 중첩되고,상기 수광 소자는 상기 제 1 도전층의 상기 개구 중 다른 하나와 중첩되는, 표시 장치.',
#      'independent': False},
#     'claim6': {'content': '공통층을 더 포함하고,상기 공통층은 상기 제 1 화소 전극과 상기 공통 전극 사이의 부분 및 상기 제 2 화소 전극과 상기 공통 전극 사이의 부분을 포함하고,상기 발광층과 상기 활성층은 상이한 유기 화합물을 포함하는, 표시 장치.',
#      'independent': False},
#     'claim7': {'content': '표시 소자와 수광 소자가 매트릭스로 배치된 표시부, 상기 표시부에 대한 터치를 검출하는 터치 센서, 및 인증부를 포함하는 전자 기기의 인증 방법으로서,상기 터치 센서에 의하여 상기 표시부에 접촉하는 손가락의 위치 정보를 취득하는 단계;상기 표시부의, 상기 손가락에 의하여 접촉된 위치를 포함하는 상기 제 1 영역에서 상기 표시 소자를 점등하는 단계;상기 수광 소자에 의하여 상기 제 1 영역을 촬상하여, 지문 정보를 취득하는 단계; 및상기 인증부에 의하여 상기 지문 정보를 사용하여 사용자 인증 처리를 실행하는 단계를 포함하는, 인증 방법.',
#      'independent': True},
#     'claim8': {'content': '표시 소자와 수광 소자가 매트릭스로 배치된 표시부, 상기 표시부에 대한 터치를 검출하는 터치 센서, 및 인증부를 포함하는 전자 기기의 인증 방법으로서,사용자에게 터치 위치를 알리는 화상을 표시하는 단계;상기 터치 센서에 의하여 접촉된 상기 터치 위치를 검출하는 단계;상기 표시부의, 접촉된 상기 터치 위치를 포함하는 상기 제 1 영역에서 상기 표시 소자를 점등하는 단계;상기 수광 소자에 의하여 상기 제 1 영역을 촬상하여, 지문 정보를 취득하는 단계; 및상기 인증부에 의하여 상기 지문 정보를 사용하여 사용자 인증 처리를 실행하는 단계를 포함하는, 인증 방법.',
#      'independent': True}}},
#   'metadata': {'ipc': ['G06F 3/042',
#     'G06F 3/044',
#     'G06F 3/044',
#     'G06F 21/32',
#     'G06F 3/041',
#     'G06V 10/147',
#     'G06V 40/13',
#     'H10K 59/60',
#     'H10K 59/40',
#     'H10K 30/00',
#     'H10K 50/00'],
#    'priority': '일본',
#    'register': '공개',
#    'link': 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=6c650beb4cee9ce4122b704b88878c934a3a1d0969b625aa7406c8a524072ea4df64fe00c4d049614e834eb4ebcf26f385f9a59fbc6c8c65798f73a32d9b4d7a6ec5d019193e85d5'}},
#  ...]

# %%
# json 확장자로 저장
import json

with open('preprocessed_data_independent.jsonl', 'w', encoding='utf-8') as f:
    for data in results:  
        f.write(json.dumps(data, ensure_ascii=False) + '\n')
